# %%
# %matplotlib inline
import os

# %%
import datajoint as dj

# %%
import pynwb
from pynwb import NWBFile, NWBHDF5IO
import pathlib
from pipeline import lab, experiment, ephys, psth
# Out:
# Connecting sfn19_user@workshop-db.datajoint.io:3306

# %%
from pipeline.export.datajoint_to_nwb import export_to_nwb

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Objective
# We wish to create a ***computed*** table storing NWB file, with attribute type of ***filepath***. The idea is to generate NWB files, one for each session, that can be access from the file system, hence type ***filepath***, and can also be fetched and worked with as part of DatJoint pipeline. This can be accomplished with the new ***dj.AttributeAdapter*** feature.

# %% [markdown]
# ## Create a ***store*** for the filepath

# %%
exported_nwb_dir = '/home/ttngu207/data'

# %%
dj.config['stores'] = {
    'nwbstore': {'protocol': 'file',
                 'stage': exported_nwb_dir,
                 'location': exported_nwb_dir}}

# %% [markdown]
# ## Create a DataJoint AttributeAdapter for NWB object

# %% [markdown]
# Basically we will need to define an object inhereted from `dj.AttributeAdapter` and instantiated with a variable name ***nwb_obj***

# %%
class NWBAdapter(dj.AttributeAdapter):
    attribute_type = 'filepath@nwbstore'
    
    def put(self, nwbfile):
        save_file_name = ''.join([nwbfile.identifier, '.nwb'])
        with NWBHDF5IO(os.path.join(exported_nwb_dir, save_file_name), mode='w') as io:
            io.write(nwbfile)
            print(f'Write NWB 2.0 file: {save_file_name}')
        return os.path.join(exported_nwb_dir, save_file_name)
        
    def get(self, path):
        return NWBHDF5IO(path, mode='r').read()

# %% [markdown]
# #### Instantiate for use as a datajoint type

# %%
nwb_obj = NWBAdapter()

# %% [markdown]
# ## Create a new schema ***export*** and NWB table

# %%
export = dj.schema('djneuro_sfn19_export')

# %%
@export
class NWB(dj.Manual):
    definition = """
    -> experiment.Session
    ---
    nwb: <nwb_obj> 
    """

# %% [markdown]
# Note that the table definition above set the ***nwb*** attribute to be of type ***< nwb_obj >***. Hence the reason for defining ***nwbfile*** as an instant of ***NWBAdapter***

# %% [markdown]
# ## Build an NWBFile and insert into ***NWB** table

# %%
experiment.Session()
# Out:
# *subject_id    *session    session_date   username     rig
# +------------+ +---------+ +------------+ +----------+ +------+
# 210861         1           2013-07-01     Nuo Li       None
# 210861         2           2013-07-02     Nuo Li       None
# 210861         3           2013-07-03     Nuo Li       None
# 210862         1           2013-06-26     Nuo Li       None
# 210862         2           2013-06-27     Nuo Li       None
# 210862         3           2013-06-28     Nuo Li       None
# 210863         1           2013-06-26     Nuo Li       None
#    ...
#  (Total: 99)

# %%
session_key = (experiment.Session & {'subject_id': '210861', 'session': 2}).fetch1('KEY')

# %%
nwbfile = export_to_nwb(session_key, nwb_output_dir=exported_nwb_dir, save=False, overwrite=True)
# Out:
# Exporting to NWB 2.0 for session: {'subject_id': 210861, 'session': 2, 'session_date': datetime.date(2013, 7, 2), 'username': 'Nuo Li', 'rig': None}...
# /opt/conda/lib/python3.7/site-packages/pynwb/file.py:621: UserWarning: Date is missing timezone information. Updating to local timezone.
#   warn("Date is missing timezone information. Updating to local timezone.")
# /opt/conda/lib/python3.7/site-packages/pynwb/file.py:621: UserWarning: Date is missing timezone information. Updating to local timezone.
#   warn("Date is missing timezone information. Updating to local timezone.")

# %%
nwbfile
# Out:
# root <class 'pynwb.file.NWBFile'>
# Fields:
#   acquisition: {
#     BehavioralEvents <class 'pynwb.behavior.BehavioralEvents'>,
#     BehavioralTimeSeries <class 'pynwb.behavior.BehavioralTimeSeries'>
#   }
#   devices: {
#     A4x8-5mm-100-200-177 <class 'pynwb.device.Device'>,
#     LaserGem473 <class 'pynwb.device.Device'>
#   }
#   electrode_groups: {
#     silicon32_g0 <class 'pynwb.ecephys.ElectrodeGroup'>
#   }
#   electrodes: electrodes <class 'pynwb.core.DynamicTable'>
#   experimenter: Nuo Li
#   institution: Janelia Research Campus
#   ogen_sites: {
#     left_alm <class 'pynwb.ogen.OptogeneticStimulusSite'>,
#     left_pons <class 'pynwb.ogen.OptogeneticStimulusSite'>
#   }
#   subject: subject <class 'pynwb.file.Subject'>
#   trials: trials <class 'pynwb.epoch.TimeIntervals'>
#   units: units <class 'pynwb.misc.Units'>
#   virus: [{"injection_id": "1", "virus": "Addgene41015", "injection_date": "2013-05-23", "injection_volume": "30.0", "brain_location_name": "left_m2", "ml_location": "2500.0", "ap_location": "-1500.0", "dv_location": "500.0", "virus_source": "Janelia core", "virus_lot_number": "", "virus_titer": "None"}, {"injection_id": "2", "virus": "Addgene41015", "injection_date": "2013-05-23", "injection_volume": "30.0", "brain_location_name": "left_m2", "ml_location": "2500.0", "ap_location": "-1500.0", "dv_location": "850.0", "virus_source": "Janelia core", "virus_lot_number": "", "virus_titer": "None"}]

# %% [markdown]
# ### Check the units and spikes

# %%
nwbfile.units.to_dataframe()
# Out:
#    quality   posx     posy  amp  snr cell_type  \
# id
# 2     good -100.0 -550.267  NaN  NaN       Pyr
# 3     good  100.0 -350.267  NaN  NaN       Pyr
# 4     good -100.0 -450.267  NaN  NaN       Pyr
# 5     good -100.0 -350.267  NaN  NaN       Pyr
# 6     good -100.0 -650.267  NaN  NaN       Pyr
# 7     good -300.0 -550.267  NaN  NaN       Pyr
# 10    good -300.0 -850.267  NaN  NaN       Pyr
# 11    good -300.0 -350.267  NaN  NaN       Pyr
# 12    good  300.0 -450.267  NaN  NaN       Pyr
# 13    good  300.0 -750.267  NaN  NaN        FS
# 14    good  300.0 -850.267  NaN  NaN       Pyr
# 16    good  300.0 -950.267  NaN  NaN       Pyr
# 17    good  100.0 -650.267  NaN  NaN       Pyr
# 18    good  100.0 -350.267  NaN  NaN       Pyr
# 19    good  100.0 -850.267  NaN  NaN       Pyr
#
#                                           spike_times  \
# id
# 2   [109.26314320573425, 121.17209161397552, 125.2...
# 3   [120.8412642585907, 123.83551503297424, 144.59...
# 4   [1126.92128716378, 1127.0913846936683, 1130.81...
# 5   [109.45957138547516, 111.13029088983154, 111.2...
# 6   [108.79099216470337, 108.88044347772217, 108.9...
# 7   [108.32261978247976, 108.32496384689426, 108.3...
# 10  [674.9961780285645, 721.4571693060608, 721.490...
# 11  [132.8796546395569, 284.34961899320984, 284.50...
# 12  [108.86798658380127, 108.89053698787308, 109.0...
# 13  [108.45781379351234, 108.74825235614395, 108.8...
# 14  [110.54654278764343, 111.4861787796936, 120.13...
# 16  [751.7973318112793, 761.9226358777161, 791.193...
# 17  [110.97444334039307, 111.00799479493713, 111.0...
# 18  [185.00959499188232, 185.39947898693848, 185.5...
# 19  [1962.4116407687989, 2058.841150586395, 2058.8...
#
#                                            electrodes  \
# id
# 2   [(20, nan, nan, nan, -1.0, {"ml_location": "25...
# 3   [(10, nan, nan, nan, -1.0, {"ml_location": "25...
# 4   [(19, nan, nan, nan, -1.0, {"ml_location": "25...
# 5   [(18, nan, nan, nan, -1.0, {"ml_location": "25...
# 6   [(21, nan, nan, nan, -1.0, {"ml_location": "25...
# 7   [(28, nan, nan, nan, -1.0, {"ml_location": "25...
# 10  [(31, nan, nan, nan, -1.0, {"ml_location": "25...
# 11  [(26, nan, nan, nan, -1.0, {"ml_location": "25...
# 12  [(3, nan, nan, nan, -1.0, {"ml_location": "250...
# 13  [(6, nan, nan, nan, -1.0, {"ml_location": "250...
# 14  [(7, nan, nan, nan, -1.0, {"ml_location": "250...
# 16  [(8, nan, nan, nan, -1.0, {"ml_location": "250...
# 17  [(13, nan, nan, nan, -1.0, {"ml_location": "25...
# 18  [(10, nan, nan, nan, -1.0, {"ml_location": "25...
# 19  [(15, nan, nan, nan, -1.0, {"ml_location": "25...
#
#                                       electrode_group  \
# id
# 2   \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 3   \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 4   \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 5   \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 6   \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 7   \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 10  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 11  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 12  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 13  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 14  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 16  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 17  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 18  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 19  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
#
#                                         waveform_mean  \
# id
# 2   [2.9228864537202256e-05, 2.84284926345073e-05,...
# 3   [5.006836949003987e-05, 4.427708409176494e-05,...
# 4   [1.7900644338382988e-05, 1.881759288214055e-05...
# 5   [1.4178244659691839e-05, 1.4123740665604622e-0...
# 6   [2.2559186228204775e-05, 2.2324021552223898e-0...
# 7   [2.5274703117986277e-05, 2.412432922773945e-05...
# 10  [2.1812180387342468e-05, 1.948675954720962e-05...
# 11  [1.4399569039739552e-05, 1.331808914530563e-05...
# 12  [6.918093181143515e-06, 6.9638174803832934e-06...
# 13  [9.420161622350694e-06, 7.01437438572918e-06, ...
# 14  [1.5581166359011533e-05, 1.4655481387463782e-0...
# 16  [1.5605277083202988e-05, 1.610224884256751e-05...
# 17  [2.6993296044639324e-05, 2.797825448981216e-05...
# 18  [1.2493187875452e-05, 1.2715486403293554e-05, ...
# 19  [2.115650221930561e-05, 1.887410084941083e-05,...
#
#                                           waveform_sd
# id
# 2   [1.7966140626141845e-05, 1.845440552697878e-05...
# 3   [2.141107841072877e-05, 1.9222327053230733e-05...
# 4   [1.4179425243004403e-05, 1.3871909939513117e-0...
# 5   [1.3276078125989425e-05, 1.2994364926017598e-0...
# 6   [1.8439354724337774e-05, 1.846228827506651e-05...
# 7   [2.306540646069597e-05, 2.3055564978177688e-05...
# 10  [1.9222300473052763e-05, 1.9481898313880234e-0...
# 11  [1.2683150482767073e-05, 1.253133861857105e-05...
# 12  [1.4247289647013013e-05, 1.3919138637092663e-0...
# 13  [1.8215571712046547e-05, 1.8545601036645187e-0...
# 14  [1.5037832422202816e-05, 1.5270189591687606e-0...
# 16  [1.4423264510439474e-05, 1.4190512667280618e-0...
# 17  [1.6292931468972e-05, 1.6477523048911307e-05, ...
# 18  [1.233931056068406e-05, 1.2442128944012759e-05...
# 19  [1.2065771654827991e-05, 1.1160497889624303e-0...

# %% [markdown]
# ### Insert to the ***NWB*** table

# %%
NWB.insert1({**session_key, 'nwb': nwbfile})
# Out:
# Write NWB 2.0 file: ANM210861_2013-07-02_2.nwb

# %%
NWB()
# Out:
# *subject_id    *session    nwb
# +------------+ +---------+ +--------+
# 210861         2           =BLOB=
#  (Total: 1)

# %%
fetched_nwb = (NWB & session_key).fetch1('nwb')

# %%
fetched_nwb
# Out:
# root <class 'pynwb.file.NWBFile'>
# Fields:
#   acquisition: {
#     BehavioralEvents <class 'pynwb.behavior.BehavioralEvents'>,
#     BehavioralTimeSeries <class 'pynwb.behavior.BehavioralTimeSeries'>
#   }
#   devices: {
#     A4x8-5mm-100-200-177 <class 'pynwb.device.Device'>,
#     LaserGem473 <class 'pynwb.device.Device'>
#   }
#   electrode_groups: {
#     silicon32_g0 <class 'pynwb.ecephys.ElectrodeGroup'>
#   }
#   electrodes: electrodes <class 'pynwb.core.DynamicTable'>
#   experimenter: Nuo Li
#   institution: Janelia Research Campus
#   intervals: {
#     trials <class 'pynwb.epoch.TimeIntervals'>
#   }
#   ogen_sites: {
#     left_alm <class 'pynwb.ogen.OptogeneticStimulusSite'>,
#     left_pons <class 'pynwb.ogen.OptogeneticStimulusSite'>
#   }
#   subject: subject <class 'pynwb.file.Subject'>
#   trials: trials <class 'pynwb.epoch.TimeIntervals'>
#   units: units <class 'pynwb.misc.Units'>
#   virus: [{"injection_id": "1", "virus": "Addgene41015", "injection_date": "2013-05-23", "injection_volume": "30.0", "brain_location_name": "left_m2", "ml_location": "2500.0", "ap_location": "-1500.0", "dv_location": "500.0", "virus_source": "Janelia core", "virus_lot_number": "", "virus_titer": "None"}, {"injection_id": "2", "virus": "Addgene41015", "injection_date": "2013-05-23", "injection_volume": "30.0", "brain_location_name": "left_m2", "ml_location": "2500.0", "ap_location": "-1500.0", "dv_location": "850.0", "virus_source": "Janelia core", "virus_lot_number": "", "virus_titer": "None"}]

# %% [markdown]
# ### Confirmed the fetched NWB file ***units*** table

# %%
fetched_nwb.units.to_dataframe()
# Out:
#    quality   posx     posy  amp  snr cell_type  \
# id
# 2     good -100.0 -550.267  NaN  NaN       Pyr
# 3     good  100.0 -350.267  NaN  NaN       Pyr
# 4     good -100.0 -450.267  NaN  NaN       Pyr
# 5     good -100.0 -350.267  NaN  NaN       Pyr
# 6     good -100.0 -650.267  NaN  NaN       Pyr
# 7     good -300.0 -550.267  NaN  NaN       Pyr
# 10    good -300.0 -850.267  NaN  NaN       Pyr
# 11    good -300.0 -350.267  NaN  NaN       Pyr
# 12    good  300.0 -450.267  NaN  NaN       Pyr
# 13    good  300.0 -750.267  NaN  NaN        FS
# 14    good  300.0 -850.267  NaN  NaN       Pyr
# 16    good  300.0 -950.267  NaN  NaN       Pyr
# 17    good  100.0 -650.267  NaN  NaN       Pyr
# 18    good  100.0 -350.267  NaN  NaN       Pyr
# 19    good  100.0 -850.267  NaN  NaN       Pyr
#
#                                           spike_times electrodes  \
# id
# 2   [109.26314320573425, 121.17209161397552, 125.2...       None
# 3   [120.8412642585907, 123.83551503297424, 144.59...       None
# 4   [1126.92128716378, 1127.0913846936683, 1130.81...       None
# 5   [109.45957138547516, 111.13029088983154, 111.2...       None
# 6   [108.79099216470337, 108.88044347772217, 108.9...       None
# 7   [108.32261978247976, 108.32496384689426, 108.3...       None
# 10  [674.9961780285645, 721.4571693060608, 721.490...       None
# 11  [132.8796546395569, 284.34961899320984, 284.50...       None
# 12  [108.86798658380127, 108.89053698787308, 109.0...       None
# 13  [108.45781379351234, 108.74825235614395, 108.8...       None
# 14  [110.54654278764343, 111.4861787796936, 120.13...       None
# 16  [751.7973318112793, 761.9226358777161, 791.193...       None
# 17  [110.97444334039307, 111.00799479493713, 111.0...       None
# 18  [185.00959499188232, 185.39947898693848, 185.5...       None
# 19  [1962.4116407687989, 2058.841150586395, 2058.8...       None
#
#                                       electrode_group  \
# id
# 2   \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 3   \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 4   \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 5   \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 6   \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 7   \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 10  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 11  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 12  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 13  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 14  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 16  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 17  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 18  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
# 19  \nsilicon32_g0 <class 'pynwb.ecephys.Electrode...
#
#                                         waveform_mean  \
# id
# 2   [2.9228864537202256e-05, 2.84284926345073e-05,...
# 3   [5.006836949003987e-05, 4.427708409176494e-05,...
# 4   [1.7900644338382988e-05, 1.881759288214055e-05...
# 5   [1.4178244659691839e-05, 1.4123740665604622e-0...
# 6   [2.2559186228204775e-05, 2.2324021552223898e-0...
# 7   [2.5274703117986277e-05, 2.412432922773945e-05...
# 10  [2.1812180387342468e-05, 1.948675954720962e-05...
# 11  [1.4399569039739552e-05, 1.331808914530563e-05...
# 12  [6.918093181143515e-06, 6.9638174803832934e-06...
# 13  [9.420161622350694e-06, 7.01437438572918e-06, ...
# 14  [1.5581166359011533e-05, 1.4655481387463782e-0...
# 16  [1.5605277083202988e-05, 1.610224884256751e-05...
# 17  [2.6993296044639324e-05, 2.797825448981216e-05...
# 18  [1.2493187875452e-05, 1.2715486403293554e-05, ...
# 19  [2.115650221930561e-05, 1.887410084941083e-05,...
#
#                                           waveform_sd
# id
# 2   [1.7966140626141845e-05, 1.845440552697878e-05...
# 3   [2.141107841072877e-05, 1.9222327053230733e-05...
# 4   [1.4179425243004403e-05, 1.3871909939513117e-0...
# 5   [1.3276078125989425e-05, 1.2994364926017598e-0...
# 6   [1.8439354724337774e-05, 1.846228827506651e-05...
# 7   [2.306540646069597e-05, 2.3055564978177688e-05...
# 10  [1.9222300473052763e-05, 1.9481898313880234e-0...
# 11  [1.2683150482767073e-05, 1.253133861857105e-05...
# 12  [1.4247289647013013e-05, 1.3919138637092663e-0...
# 13  [1.8215571712046547e-05, 1.8545601036645187e-0...
# 14  [1.5037832422202816e-05, 1.5270189591687606e-0...
# 16  [1.4423264510439474e-05, 1.4190512667280618e-0...
# 17  [1.6292931468972e-05, 1.6477523048911307e-05, ...
# 18  [1.233931056068406e-05, 1.2442128944012759e-05...
# 19  [1.2065771654827991e-05, 1.1160497889624303e-0...

# %% [markdown]
# ## One step further, let's turn this routine into a dj.Computed table

# %%
@export
class ComputedNWB(dj.Computed):
    definition = """
    -> experiment.Session
    ---
    nwb: <nwb_obj> 
    """
    
    def make(self, key):
        exported_nwb_dir = '/home/ttngu207/data'
        nwbfile = export_to_nwb(key, nwb_output_dir=exported_nwb_dir, save=False, overwrite=True)
        self.insert1({**key, 'nwb': nwbfile})

# %%
ComputedNWB.populate()
# Out:
# Exporting to NWB 2.0 for session: {'subject_id': 210861, 'session': 1, 'session_date': datetime.date(2013, 7, 1), 'username': 'Nuo Li', 'rig': None}...
